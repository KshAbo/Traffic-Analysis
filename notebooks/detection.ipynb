# %%
import sys
import os
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.computer_vision.detector import VehicleDetector
from src.computer_vision.tracker_ultralytics import UltralyticsTracker
import cv2

detector = VehicleDetector()

video = Path.joinpath(Path.cwd().parent, "data", "dataset", "normanniles1", "normanniles1_2025-10-20-06-00-45.mp4")
cap = cv2.VideoCapture(str(video))
ret, frame = cap.read()

detections = detector.detect(frame)
