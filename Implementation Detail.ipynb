# %% [markdown]
# ### 1. Vehicle Count Metrics
# | Attribute            | Why it matters   |
# | -------------------- | ---------------- |
# | `mean_vehicle_count` | overall load     |
# | `max_vehicle_count`  | peak congestion  |
# | `vehicle_count_std`  | stop–go behavior |
#
# ### 2. Entry / Exit Flow (Approximate is OK)
# | Attribute                       | Why                |
# | ------------------------------- | ------------------ |
# | `entry_count`                   | inflow pressure    |
# | `exit_count`                    | clearance ability  |
# | `flow_imbalance = entry - exit` | congestion buildup |
#
# ### 3. Density / Queue Proxy
# | Attribute     | Why                  |
# | ------------- | -------------------- |
# | `avg_density` | sustained congestion |
# | `max_density` | gridlock indicator   |
#
# ### 4. Motion / Velocity Proxies (No Real Speed Needed)
# | Attribute               | Why                |
# | ----------------------- | ------------------ |
# | `mean_displacement`     | slowdown indicator |
# | `stop_ratio`            | queues forming     |
# | `slow_vehicle_fraction` | jam detection      |
#
# ### 5. Dwell / Waiting Time Proxies
# | Attribute       | Why                    |
# | --------------- | ---------------------- |
# | `avg_wait_time` | severity of congestion |
# | `max_wait_time` | breakdown indicator    |
#
# #### High-Impact Bonus Attributes (If Time Allows)
#
# ### 6. Entry–Exit Delay
# | Attribute                 | Why                   |
# | ------------------------- | --------------------- |
# | `entry_to_exit_time_mean` | throughput efficiency |
# | `entry_to_exit_time_std`  | instability           |
#
# ### 7. Vehicle Type Composition
# | Attribute           | Why                |
# | ------------------- | ------------------ |
# | `bus_ratio`         | buses disrupt flow |
# | `truck_ratio`       | longer dwell       |
# | `two_wheeler_ratio` | weaving behavior   |
#
#
# #### Per Camera, per minute
#
# camera_id
# minute_idx
#
# mean_vehicle_count
# max_vehicle_count
# vehicle_count_std
#
# entry_count
# exit_count
# flow_imbalance
#
# avg_density
# max_density
#
# mean_displacement
# stop_ratio
#
# avg_dwell_time
#
# bus_ratio
# truck_ratio
# two_wheeler_ratio
#
# #### Global
#
# total_entry
# total_exit
# global_flow_imbalance
# avg_roundabout_density
